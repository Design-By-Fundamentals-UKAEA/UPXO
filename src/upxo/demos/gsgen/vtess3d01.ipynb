# %% [markdown]
# # Basic grain structure gen [REPRESENTATIVE GENERATION]
#
# ##################################################################
# Build a list of potential UPXO users.
# ##################################################################

# %%
from upxo.pxtal.vortess3d import gtess3d
# Out:
# C:\Users\rg5749\AppData\Local\miniforge3\envs\shark\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rg5749\AppData\Local\miniforge3\envs\shark\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\rg5749\AppData\Local\miniforge3\envs\shark\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Set target properties

# %%
repr_prop={'vol': {'use': 'mean',
                   'mean': {'val': 10, 'dev': 20, },
                   'distr': {'filename': None, 'remol': True},
                   'consider_boundary_grains': True} 
          }

# %% [markdown]
# ## Use Pseudo-Poisson dic sampling

# %%
gt3d = gtess3d.from_seed_point_extrusion(sp_input='gen', seed_coords=None,
                                         xbound=[0, 15], ybound=[0, 15], nsp=200, n_instances=2,
                                         sp_distr='random', gr_tech='pds', smp_tech='bridson1',
                                         randuni_calc='by_points', lean='veryhigh',
                                         char_length=[3, 0], niter=500, ntrials=10,
                                         k_char_length_inc=0.1, k_char_length_dec=0.05,
                                         repr_prop=repr_prop, nt=10, space='linear', nchecks=10, sdf=0.75,
                                         divergence_control=True)
# Out:
# Generating pxtal.. Iteration 1
# Creating base seed points.
# Base Seed points created.
# ----------------------------------------
# Creating all remaining seed points.
# distance along z:  1.6806305532728272
# distance along z:  2.5209458299092407
# distance along z:  3.3612611065456544
# distance along z:  4.201576383182068
# distance along z:  5.041891659818481
# distance along z:  5.882206936454895
# distance along z:  6.722522213091309
# distance along z:  7.562837489727722
# distance along z:  8.403152766364135
# distance along z:  9.243468043000549
# distance along z:  10.083783319636963
# distance along z:  10.924098596273376
# distance along z:  11.76441387290979
# distance along z:  12.604729149546204
# distance along z:  13.445044426182617
# distance along z:  14.285359702819031
# distance along z:  15.125674979455445
# ----------------------------------------
# All Seed points created.
# No. of seed points: 532
# ################################################## dict_keys(['pxtal', 'zbound', 'sp_mp2d_list', 'sp_coords', 'sp_coords_all', 'sp_coords_mp3d', 'sepdist_mean', 'bounds', 'bounding_box']) ##################################################
# Mean volume: 9.385754820021885
# Min volume: 1.7329319534906482
# Max volume: 30.73929805327338
# ----------------------------------------
# Grain structure search converged in 0 iterations
# Sample set parent found.
# ----
# Target mean grain volume: 10
# Sample mean grain volume: 9.385755
# ----
# Input Char. length: [3, 0]
# Final Char. length: 3
# ----
# No. of seed points: 532
# No. of grains: 532
# ----------------------------------------
# Generating instance number: 2 using sample set parent GS.
# Creating base seed points.
# Base Seed points created.
# ----------------------------------------
# Creating all remaining seed points.
# distance along z:  2.1489994772662295
# distance along z:  3.223499215899344
# distance along z:  4.297998954532459
# distance along z:  5.372498693165574
# distance along z:  6.446998431798688
# distance along z:  7.521498170431803
# distance along z:  8.595997909064918
# distance along z:  9.670497647698033
# distance along z:  10.744997386331148
# distance along z:  11.819497124964263
# distance along z:  12.893996863597376
# distance along z:  13.968496602230491
# distance along z:  15.042996340863606
# ----------------------------------------
# All Seed points created.

# %%
gt3d.visualize_multiple_voronoi_cells(1, cell_indices=None, colors=None,
                                      alpha=0.25, edge_color='black')
