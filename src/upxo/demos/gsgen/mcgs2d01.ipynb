# %% [markdown]
# # Import libraries

# %%
from upxo.ggrowth.mcgs import mcgs  # 
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\rg5749\AppData\Local\miniforge3\envs\shark\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rg5749\AppData\Local\miniforge3\envs\shark\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\rg5749\AppData\Local\miniforge3\envs\shark\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Instantiate a Monte-Carlo Grain structure temporal slice set

# %%
pxtal = mcgs(study='independent', input_dashboard='input_dashboard_for_testing_50x50_alg202.xls')
# Out:
# c:\development\m2matmod\upxo_packaged\upxo_private\src\upxo\interfaces\user_inputs
# c:\development\m2matmod\upxo_packaged\upxo_private\src\upxo\interfaces\user_inputs\input_dashboard_for_testing_50x50_alg202.xls
# Algo_hops details
# (('202.0', 100),)
# [False]

# %% [markdown]
# # Simulate the grain growth to get multiple temporal slices of the GS

# %%
pxtal.simulate()
# Out:
#  Initiating Monte-Carlo simulation
#      xmin, xmax, xinc: 0.0, 50.0, 1.0
#      ymin, ymax, yinc: 0.0, 50.0, 1.0
#      zmin, zmax, zinc: 0.0, 100.0, 1.0
#      No. of states: 32
#      Dimensionality: 2
#      Algorithm: 202.0
#
#
#
#
#
# ########################################
# 202.0
# ########################################
#     weighted (: ALG-202)
# Using ALG-200: SA's SL NL-1 TP1 C2 unweighted Q-Pott's model:
# |--------------- MC SIM RUN IN PROGRESS on: ALG200---------------|
# GS temporal slice 0 stored
#  ..............................
# Monte-Carlo temporal step = 1
# GS temporal slice 2 stored
#  ..............................
# Monte-Carlo temporal step = 3
# GS temporal slice 4 stored
#  ..............................
# Monte-Carlo temporal step = 5
# GS temporal slice 6 stored
#  ..............................
# Monte-Carlo temporal step = 7
# GS temporal slice 8 stored
#  ..............................
# Monte-Carlo temporal step = 9
# ...

# %% [markdown]
# # Detect grains in all temporal slices

# %%
pxtal.detect_grains()
# Out:
# Using scikit-image for grain identification
# MC state = 1:  Num grains = 27
# MC state = 2:  Num grains = 32
# MC state = 3:  Num grains = 32
# MC state = 4:  Num grains = 32
# MC state = 5:  Num grains = 38
# MC state = 6:  Num grains = 31
# MC state = 7:  Num grains = 32
# MC state = 8:  Num grains = 34
# MC state = 9:  Num grains = 34
# MC state = 10:  Num grains = 30
# MC state = 11:  Num grains = 39
# MC state = 12:  Num grains = 35
# MC state = 13:  Num grains = 38
# MC state = 14:  Num grains = 45
# MC state = 15:  Num grains = 40
# MC state = 16:  Num grains = 25
# MC state = 17:  Num grains = 31
# MC state = 18:  Num grains = 30
# MC state = 19:  Num grains = 30
# MC state = 20:  Num grains = 37
# MC state = 21:  Num grains = 32
# MC state = 22:  Num grains = 33
# MC state = 23:  Num grains = 39
# MC state = 24:  Num grains = 37
# MC state = 25:  Num grains = 28
# MC state = 26:  Num grains = 35
# MC state = 27:  Num grains = 37
# MC state = 28:  Num grains = 30
# ...

# %% [markdown]
# # Select a temporal slice of interest

# %%
tslice = 10

# %% [markdown]
# # Characterize this temporal slice for morphological properties

# %%
pxtal.gs[tslice].char_morph_2d(char_gb=True)
# Out:
# Extracting requested GS props across all available states
# --------State value: 5 of 32
# --------State value: 10 of 32
# --------State value: 15 of 32
# --------State value: 20 of 32
# --------State value: 25 of 32
# --------State value: 30 of 32
# ----------------------------------------

# %% [markdown]
# # Lets explore the data structure a bit

# %%
pxtal.gs[tslice]

# %% [markdown]
# ### See the Monte-Carlo state array image

# %%
pxtal.gs[tslice].s
# Out:
# array([[ 1,  3,  1, ..., 13, 13, 13],
#        [13,  1,  1, ..., 13, 13, 13],
#        [13,  1,  1, ..., 13, 13, 13],
#        ...,
#        [13, 13, 13, ...,  6, 13, 13],
#        [13, 13, 13, ..., 27,  3, 13],
#        [ 3,  3, 28, ..., 13, 13,  3]])

# %%
plt.imshow(pxtal.gs[tslice].s)
