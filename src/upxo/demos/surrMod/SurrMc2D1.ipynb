# %%
from upxo.surrModelOps.SModelJobs import mcgs2d_Surrogate as smod2d

# %%
input_dashboard = 'C:\\Development\\UPXO\\upxo_library\\src\\upxo\\demos\\surrMod\\surrMod1.xls'
sm = smod2d(input_dashboard=input_dashboard)
sm.set_NumberOfSimulations(2)
sm.set_export_parameters(basePath="C:\\Development\\UPXO\\upxo_library\\data\\SurrogateModelExports",
                         baseFilename="sim.",
                         fileType="npz",
                         fileNamePadLength=5)
sm.makeImages(TemporalOrSimFolders='sim', compression=False, fileLevelCompression=True)
# Out:
# C:\Development\UPXO\upxo_library\src\upxo\interfaces\user_inputs
# C:\Development\UPXO\upxo_library\src\upxo\demos\surrMod\surrMod1.xls
# Algo_hops details
# (('200.0', 100),)
# [False]
#
#  Initiating Monte-Carlo simulation
#      xmin, xmax, xinc: 0.0, 1000.0, 1.0
#      ymin, ymax, yinc: 0.0, 1000.0, 1.0
#      zmin, zmax, zinc: 0.0, 100.0, 1.0
#      No. of states: 8
#      Dimensionality: 2
# Using ALG-200: SA's SL NL-1 TP1 C2 unweighted Q-Pott's model:
# |--------------- MC SIM RUN IN PROGRESS on: ALG200---------------|
# GS temporal slice 0 stored
# GS temporal slice 1 stored
# GS temporal slice 2 stored
# GS temporal slice 3 stored
# GS temporal slice 4 stored
# GS temporal slice 5 stored
# GS temporal slice 6 stored
# GS temporal slice 7 stored
# GS temporal slice 8 stored
# GS temporal slice 9 stored
# |--------------- MC SIM RUN COMPLETED on: ALG200---------------|
# Using scikit-image for grain identification
# ...

# %%
sm.currentExportDirs
# Out:
# {0: 'C:\\Development\\UPXO\\upxo_library\\data\\SurrogateModelExports\\Path_00001',
#  1: 'C:\\Development\\UPXO\\upxo_library\\data\\SurrogateModelExports\\Path_00002'}
